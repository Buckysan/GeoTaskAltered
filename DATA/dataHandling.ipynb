# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/taigakawadawilliams/Documents/BMS/Coding/GeoTask-main/DATA/processed_data.csv')
data
# Out:
#    trial  subtrial participantID  feedback  scenarioID trueCountry  \
# 0      1         1        56bngk     False           1    Colombia
# 1      1         2        56bngk     False           2    Colombia
# 2      1         3        56bngk     False           3    Colombia
#
#    expCondition requestedInfoIdxs               requestedInfoText  \
# 0  Non-Directed             ['1']                        ['Area']
# 1  Non-Directed             ['1']      ['GDP per capita in 2022']
# 2  Non-Directed             ['4']  ['Unemployment Rate % (2021)']
#
#    numOfRequestedInfo                                      availableInfo  \
# 0                   1  ['Area', 'Number of other countries it shares ...
# 1                   1  ['GDP per capita in 2022', 'Most Exported Food...
# 2                   1  ['Overall population', 'Population in the capi...
#
#       rts  totalInfoSeekingTime           differentials likelihoods  \
# ...
